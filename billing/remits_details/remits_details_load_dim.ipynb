# %%
landing_table=dbutils.widgets.get("landing_table")
landing_flattened_table=dbutils.widgets.get("landing_flattened_table")
raw_table=dbutils.widgets.get("raw_table")
volume_path=dbutils.widgets.get("volume_path")

# %%
try:
    spark.sql(f"""
        WITH latest_src AS (
            SELECT *
            FROM (
                SELECT
                    *,
                    ROW_NUMBER() OVER (
                        PARTITION BY TransID, Services_LineNo, Services_HCPC,Services_AdjHCPC, Services_LocationNo, Services_Modifier1, Services_Modifier2, Services_Modifier3, Services_Modifier4, Services_Units, Services_UnitsPaid, Services_RenderingProvID_CommercialNo, Services_RenderingProvID_NPI, Services_RevenueCode, Services_ServiceStart, Services_ServiceEnd, Services_Adjustments_AdjAmount, Services_Adjustments_AdjQuantity, Services_Adjustments_GroupCode, Services_Adjustments_ReasonCode, Services_RemarkCodes_RemarkCode, Services_RemarkCodes_RemarkType
                        ORDER BY _load_timestamp DESC
                    ) AS rn
                FROM {landing_flattened_table}
            ) t
            WHERE rn = 1
        )

        MERGE INTO {raw_table} tgt
        USING latest_src src
        ON tgt.TransID = src.TransID
        AND COALESCE(tgt.Services_LineNo, -1) = COALESCE(src.Services_LineNo, -1)
        AND COALESCE(tgt.Services_HCPC, '') = COALESCE(src.Services_HCPC, '')
        AND COALESCE(tgt.Services_AdjHCPC, '') = COALESCE(src.Services_AdjHCPC, '')
        AND COALESCE(tgt.Services_LocationNo, '') = COALESCE(src.Services_LocationNo, '')
        AND COALESCE(tgt.Services_Modifier1, '') = COALESCE(src.Services_Modifier1, '')
        AND COALESCE(tgt.Services_Modifier2, '') = COALESCE(src.Services_Modifier2, '')
        AND COALESCE(tgt.Services_Modifier3, '') = COALESCE(src.Services_Modifier3, '')
        AND COALESCE(tgt.Services_Modifier4, '') = COALESCE(src.Services_Modifier4, '')
        AND COALESCE(tgt.Services_Units, -1) = COALESCE(src.Services_Units, -1)
        AND COALESCE(tgt.Services_UnitsPaid, -1) = COALESCE(src.Services_UnitsPaid, -1)
        AND COALESCE(tgt.Services_RenderingProvID_CommercialNo, -1)
            = COALESCE(src.Services_RenderingProvID_CommercialNo, -1)
        AND COALESCE(tgt.Services_RenderingProvID_NPI, -1)
            = COALESCE(src.Services_RenderingProvID_NPI, -1)
        AND COALESCE(tgt.Services_RevenueCode, '') = COALESCE(src.Services_RevenueCode, '')
        AND COALESCE(tgt.Services_ServiceStart, '') = COALESCE(src.Services_ServiceStart, '')
        AND COALESCE(tgt.Services_ServiceEnd, '') = COALESCE(src.Services_ServiceEnd, '')
        AND COALESCE(tgt.Services_Adjustments_AdjAmount, -1)
            = COALESCE(src.Services_Adjustments_AdjAmount, -1)
        AND COALESCE(tgt.Services_Adjustments_AdjQuantity, -1)
            = COALESCE(src.Services_Adjustments_AdjQuantity, -1)
        AND COALESCE(tgt.Services_Adjustments_GroupCode, '')
            = COALESCE(src.Services_Adjustments_GroupCode, '')
        AND COALESCE(tgt.Services_Adjustments_ReasonCode, '')
            = COALESCE(src.Services_Adjustments_ReasonCode, '')
        AND COALESCE(tgt.Services_RemarkCodes_RemarkCode, '')
            = COALESCE(src.Services_RemarkCodes_RemarkCode, '')
        AND COALESCE(tgt.Services_RemarkCodes_RemarkType, '')
            = COALESCE(src.Services_RemarkCodes_RemarkType, '')

        AND tgt._modified_ts < src._load_timestamp
        AND tgt._active_flag = 1

        WHEN MATCHED THEN
            UPDATE SET
                tgt._active_flag = 0,
                tgt._modified_ts = src._load_timestamp
    """)
except Exception as e:
    print(f"Error updating {raw_table}: {e}")
    raise

# %%
try:
    spark.sql(f"""     
        WITH latest_src AS (
            SELECT *
            FROM (
                SELECT
                    *,
                    ROW_NUMBER() OVER (
                        PARTITION BY TransID, Services_LineNo, Services_HCPC,Services_AdjHCPC, Services_LocationNo, Services_Modifier1, Services_Modifier2, Services_Modifier3, Services_Modifier4, Services_Units, Services_UnitsPaid, Services_RenderingProvID_CommercialNo, Services_RenderingProvID_NPI, Services_RevenueCode, Services_ServiceStart, Services_ServiceEnd, Services_Adjustments_AdjAmount, Services_Adjustments_AdjQuantity, Services_Adjustments_GroupCode, Services_Adjustments_ReasonCode, Services_RemarkCodes_RemarkCode, Services_RemarkCodes_RemarkType
                        ORDER BY _load_timestamp DESC
                    ) AS rn
                FROM {landing_flattened_table}
            ) t
            WHERE rn = 1
        )
        MERGE INTO {raw_table} tgt
        USING latest_src src
        ON tgt.TransID = src.TransID
        AND COALESCE(tgt.Services_LineNo, -1) = COALESCE(src.Services_LineNo, -1)
        AND COALESCE(tgt.Services_HCPC, '') = COALESCE(src.Services_HCPC, '')
        AND COALESCE(tgt.Services_AdjHCPC, '') = COALESCE(src.Services_AdjHCPC, '')
        AND COALESCE(tgt.Services_LocationNo, '') = COALESCE(src.Services_LocationNo, '')
        AND COALESCE(tgt.Services_Modifier1, '') = COALESCE(src.Services_Modifier1, '')
        AND COALESCE(tgt.Services_Modifier2, '') = COALESCE(src.Services_Modifier2, '')
        AND COALESCE(tgt.Services_Modifier3, '') = COALESCE(src.Services_Modifier3, '')
        AND COALESCE(tgt.Services_Modifier4, '') = COALESCE(src.Services_Modifier4, '')
        AND COALESCE(tgt.Services_Units, -1) = COALESCE(src.Services_Units, -1)
        AND COALESCE(tgt.Services_UnitsPaid, -1) = COALESCE(src.Services_UnitsPaid, -1)
        AND COALESCE(tgt.Services_RenderingProvID_CommercialNo, -1)
            = COALESCE(src.Services_RenderingProvID_CommercialNo, -1)
        AND COALESCE(tgt.Services_RenderingProvID_NPI, -1)
            = COALESCE(src.Services_RenderingProvID_NPI, -1)
        AND COALESCE(tgt.Services_RevenueCode, '') = COALESCE(src.Services_RevenueCode, '')
        AND COALESCE(tgt.Services_ServiceStart, '') = COALESCE(src.Services_ServiceStart, '')
        AND COALESCE(tgt.Services_ServiceEnd, '') = COALESCE(src.Services_ServiceEnd, '')
        AND COALESCE(tgt.Services_Adjustments_AdjAmount, -1)
            = COALESCE(src.Services_Adjustments_AdjAmount, -1)
        AND COALESCE(tgt.Services_Adjustments_AdjQuantity, -1)
            = COALESCE(src.Services_Adjustments_AdjQuantity, -1)
        AND COALESCE(tgt.Services_Adjustments_GroupCode, '')
            = COALESCE(src.Services_Adjustments_GroupCode, '')
        AND COALESCE(tgt.Services_Adjustments_ReasonCode, '')
            = COALESCE(src.Services_Adjustments_ReasonCode, '')
        AND COALESCE(tgt.Services_RemarkCodes_RemarkCode, '')
            = COALESCE(src.Services_RemarkCodes_RemarkCode, '')
        AND COALESCE(tgt.Services_RemarkCodes_RemarkType, '')
            = COALESCE(src.Services_RemarkCodes_RemarkType, '')

        AND tgt._created_ts = src._load_timestamp

        WHEN NOT MATCHED THEN
            INSERT (
                AdjAmounts,
                Adjustments_AdjAmount,
                Adjustments_AdjQuantity,
                Adjustments_GroupCode,
                Adjustments_ReasonCode,
                AppealCreated,
                AppealCreation,
                AppealResults,
                AppealType,
                AppealTypeName,
                AppealTypes,
                AssignedToID,
                Balanced,
                ClaimCharge,
                ClaimFilingCode,
                ClaimFreqCode,
                ClaimPayment,
                ClassContractNo,
                CoverageAmt,
                CrcPatientFirst,
                CrcPatientID_ChangedID,
                CrcPatientLast,
                CrcPayerID_PayerID,
                CrcPayerName,
                CreateDate,
                CreateMode,
                CrossoverCarrier,
                CrossoverCarrierID_PayerID,
                CustomGroup,
                DRGCode,
                DRGWeight,
                DischargeFraction,
                EditByID,
                EditDate,
                ExpirationDate,
                FacilityType,
                GroupNo,
                ImportBatchID,
                Interest,
                LastUpdated,
                LastUpdatedUserId,
                LastUserUpdatedDate,
                MedRecordNo,
                MediaCode,
                MemberID,
                OrigRefNo,
                ParentID,
                PatID,
                PatientCtlNo,
                PatientFirst,
                PatientID_MedicaidID,
                PatientID_MemberID,
                PatientLast,
                PatientMiddle,
                PatientResp,
                PayerCtlNo,
                PayerMatchID,
                PayerPartnerID,
                PriorAuthNo,
                ProvMatchID,
                ProvPartnerID,
                ReceivedDate,
                RemarkCodes_RemarkCode,
                RemarkCodes_RemarkType,
                RemitClaimID,
                RemitGroupID,
                RemitPaymentID,
                RenderingProvFirst,
                RenderingProvID_NPI,
                RenderingProvID_ProvCommNo,
                RenderingProvLast,
                Services_AdjHCPC,
                Services_Adjustments_AdjAmount,
                Services_Adjustments_AdjQuantity,
                Services_Adjustments_GroupCode,
                Services_Adjustments_ReasonCode,
                Services_Allowed,
                Services_AuthNo,
                Services_Balanced,
                Services_Charge,
                Services_HCPC,
                Services_LineNo,
                Services_LocationNo,
                Services_Modifier1,
                Services_Modifier2,
                Services_Modifier3,
                Services_Modifier4,
                Services_Payment,
                Services_ProvCtlNo,
                Services_RemarkCodes_RemarkCode,
                Services_RemarkCodes_RemarkType,
                Services_RenderingProvID_CommercialNo,
                Services_RenderingProvID_NPI,
                Services_RevenueCode,
                Services_ServiceEnd,
                Services_ServiceStart,
                Services_Underpayment,
                Services_UnderpaymentAmount,
                Services_Units,
                Services_UnitsPaid,
                SourceFileID,
                StatementEnd,
                StatementStart,
                StatusCode,
                SubscriberFirst,
                SubscriberID_MemberID,
                SubscriberLast,
                SubscriberMiddle,
                TransID,
                TransStatus,
                TransType,
                TransmitDate,
                Underpayment,
                UnderpaymentAmount,
                WorkQueue,
                _file_name,
                _created_ts,
                _modified_ts,
                _active_flag
            )
            VALUES (
                src.AdjAmounts,
                src.Adjustments_AdjAmount,
                src.Adjustments_AdjQuantity,
                src.Adjustments_GroupCode,
                src.Adjustments_ReasonCode,
                src.AppealCreated,
                src.AppealCreation,
                src.AppealResults,
                src.AppealType,
                src.AppealTypeName,
                src.AppealTypes,
                src.AssignedToID,
                src.Balanced,
                src.ClaimCharge,
                src.ClaimFilingCode,
                src.ClaimFreqCode,
                src.ClaimPayment,
                src.ClassContractNo,
                src.CoverageAmt,
                src.CrcPatientFirst,
                src.CrcPatientID_ChangedID,
                src.CrcPatientLast,
                src.CrcPayerID_PayerID,
                src.CrcPayerName,
                src.CreateDate,
                src.CreateMode,
                src.CrossoverCarrier,
                src.CrossoverCarrierID_PayerID,
                src.CustomGroup,
                src.DRGCode,
                src.DRGWeight,
                src.DischargeFraction,
                src.EditByID,
                src.EditDate,
                src.ExpirationDate,
                src.FacilityType,
                src.GroupNo,
                src.ImportBatchID,
                src.Interest,
                src.LastUpdated,
                src.LastUpdatedUserId,
                src.LastUserUpdatedDate,
                src.MedRecordNo,
                src.MediaCode,
                src.MemberID,
                src.OrigRefNo,
                src.ParentID,
                src.PatID,
                src.PatientCtlNo,
                src.PatientFirst,
                src.PatientID_MedicaidID,
                src.PatientID_MemberID,
                src.PatientLast,
                src.PatientMiddle,
                src.PatientResp,
                src.PayerCtlNo,
                src.PayerMatchID,
                src.PayerPartnerID,
                src.PriorAuthNo,
                src.ProvMatchID,
                src.ProvPartnerID,
                src.ReceivedDate,
                src.RemarkCodes_RemarkCode,
                src.RemarkCodes_RemarkType,
                src.RemitClaimID,
                src.RemitGroupID,
                src.RemitPaymentID,
                src.RenderingProvFirst,
                src.RenderingProvID_NPI,
                src.RenderingProvID_ProvCommNo,
                src.RenderingProvLast,
                src.Services_AdjHCPC,
                src.Services_Adjustments_AdjAmount,
                src.Services_Adjustments_AdjQuantity,
                src.Services_Adjustments_GroupCode,
                src.Services_Adjustments_ReasonCode,
                src.Services_Allowed,
                src.Services_AuthNo,
                src.Services_Balanced,
                src.Services_Charge,
                src.Services_HCPC,
                src.Services_LineNo,
                src.Services_LocationNo,
                src.Services_Modifier1,
                src.Services_Modifier2,
                src.Services_Modifier3,
                src.Services_Modifier4,
                src.Services_Payment,
                src.Services_ProvCtlNo,
                src.Services_RemarkCodes_RemarkCode,
                src.Services_RemarkCodes_RemarkType,
                src.Services_RenderingProvID_CommercialNo,
                src.Services_RenderingProvID_NPI,
                src.Services_RevenueCode,
                src.Services_ServiceEnd,
                src.Services_ServiceStart,
                src.Services_Underpayment,
                src.Services_UnderpaymentAmount,
                src.Services_Units,
                src.Services_UnitsPaid,
                src.SourceFileID,
                src.StatementEnd,
                src.StatementStart,
                src.StatusCode,
                src.SubscriberFirst,
                src.SubscriberID_MemberID,
                src.SubscriberLast,
                src.SubscriberMiddle,
                src.TransID,
                src.TransStatus,
                src.TransType,
                src.TransmitDate,
                src.Underpayment,
                src.UnderpaymentAmount,
                src.WorkQueue,
                src._file_name,
                src._load_timestamp,
                src._load_timestamp,
                1
            );
    """)
except Exception as e:
    print(f"Error inserting into {raw_table}: {e}")
    raise
