# %%
landing_table=dbutils.widgets.get("landing_table")
landing_flattened_table=dbutils.widgets.get("landing_flattened_table")
raw_table=dbutils.widgets.get("raw_table")
volume_path=dbutils.widgets.get("volume_path")

# %%
try:
    spark.sql(f"""
        WITH new_records AS (
        SELECT src.*
        FROM {landing_table} src
        LEFT OUTER JOIN {landing_flattened_table} tgt
        ON src.transID = tgt.transID
        AND src._file_name = tgt._file_name
        WHERE tgt.transID IS NULL
        ),
        new_records_dedup AS (
        SELECT
            AcceptAssignment,
            AssignedToID,
            Attachments_expl.AttachmentTransID AS Attachments_AttachmentTransID,
            Attachments_expl.ControlNumber AS Attachments_ControlNumber,
            Attachments_expl.Description AS Attachments_Description,
            Attachments_expl.FileID AS Attachments_FileID,
            Attachments_expl.Pending AS Attachments_Pending,
            Attachments_expl.ReportType AS Attachments_ReportType,
            Attachments_expl.TranAttachmentsID AS Attachments_TranAttachmentsID,
            Attachments_expl.TransmissionCode AS Attachments_TransmissionCode,
            AttendingFirst,
            AttendingLast,
            AttendingProvID.NPI AS AttendingProvID_NPI,
            BillType,
            BillingAddr1,
            BillingCity,
            BillingEntType,
            BillingName,
            BillingProvID.CommercialNo AS BillingProvID_CommercialNo,
            BillingProvID.EIN AS BillingProvID_EIN,
            BillingProvID.NPI AS BillingProvID_NPI,
            BillingProvID.Taxonomy AS BillingProvID_Taxonomy,
            BillingState,
            BillingZip,
            Box10d,
            ClaimCharge,
            ClaimDate.Accident AS ClaimDate_Accident,
            ClaimDate.OnsetCurrent AS ClaimDate_OnsetCurrent,
            ClaimID.MammoCert AS ClaimID_MammoCert,
            ClaimID.MedicalRecNo AS ClaimID_MedicalRecNo,
            ClaimPaidInd,
            ClaimPayment,
            ClaimType,
            Contract.Code AS Contract_Code,
            CreateDate,
            CreateMode,
            DataRecord_expl AS DataRecord,
            DestInsNo,
            DiagnosisCodes10.Other1 AS DiagnosisCodes10_Other1,
            DiagnosisCodes10.Other2 AS DiagnosisCodes10_Other2,
            DiagnosisCodes10.Other3 AS DiagnosisCodes10_Other3,
            DiagnosisCodes10.Other4 AS DiagnosisCodes10_Other4,
            DiagnosisCodes10.Other5 AS DiagnosisCodes10_Other5,
            DiagnosisCodes10.Other6 AS DiagnosisCodes10_Other6,
            DiagnosisCodes10.Other7 AS DiagnosisCodes10_Other7,
            DiagnosisCodes10.Other8 AS DiagnosisCodes10_Other8,
            DiagnosisCodes10.Principal AS DiagnosisCodes10_Principal,
            DiagnosisVersion,
            EditByID,
            EditDate,
            ImportBatchID,
            InsuranceLastID,
            Insurances.`1`.AssignBenefits AS Insurances_1_AssignBenefits,
            Insurances.`1`.ClaimIndCode AS Insurances_1_ClaimIndCode,
            Insurances.`1`.GroupNumber AS Insurances_1_GroupNumber,
            Insurances.`1`.InsuranceID AS Insurances_1_InsuranceID,
            Insurances.`1`.PatientRelateCode AS Insurances_1_PatientRelateCode,
            Insurances.`1`.PayerAddr1 AS Insurances_1_PayerAddr1,
            Insurances.`1`.PayerCity AS Insurances_1_PayerCity,
            Insurances.`1`.PayerICN AS Insurances_1_PayerICN,
            Insurances.`1`.PayerID.ClmOfficeNo AS Insurances_1_PayerID_ClmOfficeNo,
            Insurances.`1`.PayerID.ID AS Insurances_1_PayerID_ID,
            Insurances.`1`.PayerID.Local AS Insurances_1_PayerID_Local,
            Insurances.`1`.PayerID.LocalIndCode AS Insurances_1_PayerID_LocalIndCode,
            Insurances.`1`.PayerName AS Insurances_1_PayerName,
            Insurances.`1`.PayerPartnerID AS Insurances_1_PayerPartnerID,
            Insurances.`1`.PayerSeqCode AS Insurances_1_PayerSeqCode,
            Insurances.`1`.PayerSeqNo AS Insurances_1_PayerSeqNo,
            Insurances.`1`.PayerState AS Insurances_1_PayerState,
            Insurances.`1`.PayerZip AS Insurances_1_PayerZip,
            Insurances.`1`.PriorAuthNo AS Insurances_1_PriorAuthNo,
            Insurances.`1`.PropertyClmNo AS Insurances_1_PropertyClmNo,
            Insurances.`1`.ReleaseInfoCode AS Insurances_1_ReleaseInfoCode,
            Insurances.`1`.SubscriberAddr1 AS Insurances_1_SubscriberAddr1,
            Insurances.`1`.SubscriberAddr2 AS Insurances_1_SubscriberAddr2,
            Insurances.`1`.SubscriberCity AS Insurances_1_SubscriberCity,
            Insurances.`1`.SubscriberDOB AS Insurances_1_SubscriberDOB,
            Insurances.`1`.SubscriberFirst AS Insurances_1_SubscriberFirst,
            Insurances.`1`.SubscriberGender AS Insurances_1_SubscriberGender,
            Insurances.`1`.SubscriberID.MemberID AS Insurances_1_SubscriberID_MemberID,
            Insurances.`1`.SubscriberLast AS Insurances_1_SubscriberLast,
            Insurances.`1`.SubscriberMiddle AS Insurances_1_SubscriberMiddle,
            Insurances.`1`.SubscriberState AS Insurances_1_SubscriberState,
            Insurances.`1`.SubscriberZip AS Insurances_1_SubscriberZip,
            LastUpdated,
            LastUpdatedUserId,
            LastUserUpdatedDate,
            MediaCode,
            NoteLastID,
            Notes,
            ParentID,
            PatID,
            PatientAddr1,
            PatientAddr2,
            PatientCity,
            PatientCtlNo,
            PatientDOB,
            PatientFirst,
            PatientGender,
            PatientLast,
            PatientMiddle,
            PatientState,
            PatientZip,
            PayToAddr1,
            PayToCity,
            PayToName,
            PayToProvID.NPI AS PayToProvID_NPI,
            PayToProvID.Taxonomy AS PayToProvID_Taxonomy,
            PayToState,
            PayToZip,
            PayerMatchID,
            PayerPartnerID,
            PaymentDate,
            PrintMail,
            ProcedureVersion,
            ProvMatchID,
            ProvPartnerID,
            ReferringFirst,
            ReferringLast,
            ReferringMiddle,
            ReferringProvID.NPI AS ReferringProvID_NPI,
            ReimbursementAmount,
            RelatedEmployment,
            ReleaseToDde,
            RemitClaimID,
            RenderingEntType,
            RenderingFirst,
            RenderingLast,
            RenderingMiddle,
            RenderingProvID.NPI AS RenderingProvID_NPI,
            RenderingProvID.Taxonomy AS RenderingProvID_Taxonomy,
            RenderingSuffix,
            RuleOverrides_expl AS RuleOverrides,
            ServiceAddr1,
            ServiceAddr2,
            ServiceCity,
            ServiceLastID,
            ServiceName,
            ServiceState,
            ServiceZip,
            ServiceLineNo,
            service_map.Services.ThroughDate AS Services_ThroughDate,
            service_map.Services.DiagnosisPointer AS Services_DiagnosisPointer,
            service_map.Services.OrderingMiddle AS Services_OrderingMiddle,
            service_map.Services.Charge AS Services_Charge,
            service_map.Services.OrderingProvID.NPI AS Services_OrderingProvID_NPI,
            service_map.Services.RenderingProvID.NPI AS Services_RenderingProvID_NPI,
            service_map.Services.Units AS Services_Units,
            service_map.Services.HCPC AS Services_HCPC,
            service_map.Services.ServiceID AS Services_ServiceID,
            service_map.Services.OrderingSuffix AS Services_OrderingSuffix,
            service_map.Services.PlaceService AS Services_PlaceService,
            service_map.Services.UnderpaymentAmount AS Services_UnderpaymentAmount,
            service_map.Services.OrderingFirst AS Services_OrderingFirst,
            service_map.Services.ReferringSuffix AS Services_ReferringSuffix,
            service_map.Services.OrderingLast AS Services_OrderingLast,
            service_map.Services.RenderingLast AS Services_RenderingLast,
            service_map.Services.FromDate AS Services_FromDate,
            service_map.Services.LineNo AS Services_LineNo,
            SignatureOnFile,
            SourceFileID,
            StatementEnd,
            StatementStart,
            TransID,
            TransStatus,
            TransType,
            TransmitDate,
            UnderpaymentAmount,
            adj_icn,
            _file_name,
            _load_timestamp
        FROM new_records
        LATERAL VIEW explode_outer(Attachments) Attachments_lv AS Attachments_expl
        LATERAL VIEW explode_outer(DataRecord) DataRecord_lv AS DataRecord_expl
        LATERAL VIEW explode_outer(RuleOverrides) RuleOverrides_lv AS RuleOverrides_expl
        LATERAL VIEW explode_outer(from_json(Services,'map<string, struct<
                    ThroughDate:string,
                    DiagnosisPointer:string,
                    OrderingMiddle:string,
                    Charge:string,
                    OrderingProvID:struct<NPI:string>,
                    RenderingProvID:struct<NPI:string>,
                    Units:string,
                    HCPC:string,
                    ServiceID:int,
                    OrderingSuffix:string,
                    PlaceService:string,
                    UnderpaymentAmount:double,
                    OrderingFirst:string,
                    ReferringSuffix:string,
                    OrderingLast:string,
                    RenderingLast:string,
                    FromDate:string,
                    LineNo:int
                >>'
            )
        ) service_map AS ServiceLineNo, Services

        ),
        new_records_final AS (
        SELECT
            COALESCE(TRY_CAST(AcceptAssignment AS STRING),'') AS AcceptAssignment,
            COALESCE(TRY_CAST(AssignedToID AS BIGINT),0) AS AssignedToID,
            COALESCE(TRY_CAST(Attachments_AttachmentTransID AS STRING),'') AS Attachments_AttachmentTransID,
            COALESCE(TRY_CAST(Attachments_ControlNumber AS STRING),'') AS Attachments_ControlNumber,
            COALESCE(TRY_CAST(Attachments_Description AS STRING),'') AS Attachments_Description,
            COALESCE(TRY_CAST(Attachments_FileID AS STRING),'') AS Attachments_FileID,
            COALESCE(TRY_CAST(Attachments_Pending AS STRING),'') AS Attachments_Pending,
            COALESCE(TRY_CAST(Attachments_ReportType AS STRING),'') AS Attachments_ReportType,
            COALESCE(TRY_CAST(Attachments_TranAttachmentsID AS STRING),'') AS Attachments_TranAttachmentsID,
            COALESCE(TRY_CAST(Attachments_TransmissionCode AS STRING),'') AS Attachments_TransmissionCode,
            COALESCE(TRY_CAST(AttendingFirst AS STRING),'') AS AttendingFirst,
            COALESCE(TRY_CAST(AttendingLast AS STRING),'') AS AttendingLast,
            COALESCE(TRY_CAST(AttendingProvID_NPI AS STRING),'') AS AttendingProvID_NPI,
            COALESCE(TRY_CAST(BillType AS STRING),'') AS BillType,
            COALESCE(TRY_CAST(BillingAddr1 AS STRING),'') AS BillingAddr1,
            COALESCE(TRY_CAST(BillingCity AS STRING),'') AS BillingCity,
            COALESCE(TRY_CAST(BillingEntType AS STRING),'') AS BillingEntType,
            COALESCE(TRY_CAST(BillingName AS STRING),'') AS BillingName,
            COALESCE(TRY_CAST(BillingProvID_CommercialNo AS STRING),'') AS BillingProvID_CommercialNo,
            COALESCE(TRY_CAST(BillingProvID_EIN AS STRING),'') AS BillingProvID_EIN,
            COALESCE(TRY_CAST(BillingProvID_NPI AS STRING),'') AS BillingProvID_NPI,
            COALESCE(TRY_CAST(BillingProvID_Taxonomy AS STRING),'') AS BillingProvID_Taxonomy,
            COALESCE(TRY_CAST(BillingState AS STRING),'') AS BillingState,
            COALESCE(TRY_CAST(BillingZip AS STRING),'') AS BillingZip,
            COALESCE(TRY_CAST(Box10d AS STRING),'') AS Box10d,
            COALESCE(TRY_CAST(ClaimCharge AS DECIMAL(10,2)),CAST(0 AS DECIMAL(10,2))) AS ClaimCharge,
            COALESCE(TRY_CAST(ClaimDate_Accident AS STRING),'') AS ClaimDate_Accident,
            COALESCE(TRY_CAST(ClaimDate_OnsetCurrent AS STRING),'') AS ClaimDate_OnsetCurrent,
            COALESCE(TRY_CAST(ClaimID_MammoCert AS STRING),'') AS ClaimID_MammoCert,
            COALESCE(TRY_CAST(ClaimID_MedicalRecNo AS STRING),'') AS ClaimID_MedicalRecNo,
            COALESCE(TRY_CAST(ClaimPaidInd AS STRING),'') AS ClaimPaidInd,
            COALESCE(TRY_CAST(ClaimPayment AS DECIMAL(10,2)),CAST(0 AS DECIMAL(10,2))) AS ClaimPayment,
            COALESCE(TRY_CAST(ClaimType AS STRING),'') AS ClaimType,
            COALESCE(TRY_CAST(Contract_Code AS STRING),'') AS Contract_Code,
            COALESCE(TRY_CAST(CreateDate AS STRING),'') AS CreateDate,
            COALESCE(TRY_CAST(CreateMode AS STRING),'') AS CreateMode,
            COALESCE(TRY_CAST(DataRecord AS STRING),'') AS DataRecord,
            COALESCE(TRY_CAST(DestInsNo AS BIGINT),0) AS DestInsNo,
            COALESCE(TRY_CAST(DiagnosisCodes10_Other1 AS STRING),'') AS DiagnosisCodes10_Other1,
            COALESCE(TRY_CAST(DiagnosisCodes10_Other2 AS STRING),'') AS DiagnosisCodes10_Other2,
            COALESCE(TRY_CAST(DiagnosisCodes10_Other3 AS STRING),'') AS DiagnosisCodes10_Other3,
            COALESCE(TRY_CAST(DiagnosisCodes10_Other4 AS STRING),'') AS DiagnosisCodes10_Other4,
            COALESCE(TRY_CAST(DiagnosisCodes10_Other5 AS STRING),'') AS DiagnosisCodes10_Other5,
            COALESCE(TRY_CAST(DiagnosisCodes10_Other6 AS STRING),'') AS DiagnosisCodes10_Other6,
            COALESCE(TRY_CAST(DiagnosisCodes10_Other7 AS STRING),'') AS DiagnosisCodes10_Other7,
            COALESCE(TRY_CAST(DiagnosisCodes10_Other8 AS STRING),'') AS DiagnosisCodes10_Other8,
            COALESCE(TRY_CAST(DiagnosisCodes10_Principal AS STRING),'') AS DiagnosisCodes10_Principal,
            COALESCE(TRY_CAST(DiagnosisVersion AS STRING),'') AS DiagnosisVersion,
            COALESCE(TRY_CAST(EditByID AS STRING),'') AS EditByID,
            COALESCE(TRY_CAST(EditDate AS STRING),'') AS EditDate,
            COALESCE(TRY_CAST(ImportBatchID AS STRING),'') AS ImportBatchID,
            COALESCE(TRY_CAST(InsuranceLastID AS BIGINT),0) AS InsuranceLastID,
            COALESCE(TRY_CAST(Insurances_1_AssignBenefits AS STRING),'') AS Insurances_1_AssignBenefits,
            COALESCE(TRY_CAST(Insurances_1_ClaimIndCode AS STRING),'') AS Insurances_1_ClaimIndCode,
            COALESCE(TRY_CAST(Insurances_1_GroupNumber AS STRING),'') AS Insurances_1_GroupNumber,
            COALESCE(TRY_CAST(Insurances_1_InsuranceID AS BIGINT),0) AS Insurances_1_InsuranceID,
            COALESCE(TRY_CAST(Insurances_1_PatientRelateCode AS STRING),'') AS Insurances_1_PatientRelateCode,
            COALESCE(TRY_CAST(Insurances_1_PayerAddr1 AS STRING),'') AS Insurances_1_PayerAddr1,
            COALESCE(TRY_CAST(Insurances_1_PayerCity AS STRING),'') AS Insurances_1_PayerCity,
            COALESCE(TRY_CAST(Insurances_1_PayerICN AS STRING),'') AS Insurances_1_PayerICN,
            COALESCE(TRY_CAST(Insurances_1_PayerID_ClmOfficeNo AS STRING),'') AS Insurances_1_PayerID_ClmOfficeNo,
            COALESCE(TRY_CAST(Insurances_1_PayerID_ID AS STRING),'') AS Insurances_1_PayerID_ID,
            COALESCE(TRY_CAST(Insurances_1_PayerID_Local AS STRING),'') AS Insurances_1_PayerID_Local,
            COALESCE(TRY_CAST(Insurances_1_PayerID_LocalIndCode AS STRING),'') AS Insurances_1_PayerID_LocalIndCode,
            COALESCE(TRY_CAST(Insurances_1_PayerName AS STRING),'') AS Insurances_1_PayerName,
            COALESCE(TRY_CAST(Insurances_1_PayerPartnerID AS STRING),'') AS Insurances_1_PayerPartnerID,
            COALESCE(TRY_CAST(Insurances_1_PayerSeqCode AS STRING),'') AS Insurances_1_PayerSeqCode,
            COALESCE(TRY_CAST(Insurances_1_PayerSeqNo AS STRING),'') AS Insurances_1_PayerSeqNo,
            COALESCE(TRY_CAST(Insurances_1_PayerState AS STRING),'') AS Insurances_1_PayerState,
            COALESCE(TRY_CAST(Insurances_1_PayerZip AS STRING),'') AS Insurances_1_PayerZip,
            COALESCE(TRY_CAST(Insurances_1_PriorAuthNo AS STRING),'') AS Insurances_1_PriorAuthNo,
            COALESCE(TRY_CAST(Insurances_1_PropertyClmNo AS STRING),'') AS Insurances_1_PropertyClmNo,
            COALESCE(TRY_CAST(Insurances_1_ReleaseInfoCode AS STRING),'') AS Insurances_1_ReleaseInfoCode,
            COALESCE(TRY_CAST(Insurances_1_SubscriberAddr1 AS STRING),'') AS Insurances_1_SubscriberAddr1,
            COALESCE(TRY_CAST(Insurances_1_SubscriberAddr2 AS STRING),'') AS Insurances_1_SubscriberAddr2,
            COALESCE(TRY_CAST(Insurances_1_SubscriberCity AS STRING),'') AS Insurances_1_SubscriberCity,
            COALESCE(TRY_CAST(Insurances_1_SubscriberDOB AS STRING),'') AS Insurances_1_SubscriberDOB,
            COALESCE(TRY_CAST(Insurances_1_SubscriberFirst AS STRING),'') AS Insurances_1_SubscriberFirst,
            COALESCE(TRY_CAST(Insurances_1_SubscriberGender AS STRING),'') AS Insurances_1_SubscriberGender,
            COALESCE(TRY_CAST(Insurances_1_SubscriberID_MemberID AS STRING),'') AS Insurances_1_SubscriberID_MemberID,
            COALESCE(TRY_CAST(Insurances_1_SubscriberLast AS STRING),'') AS Insurances_1_SubscriberLast,
            COALESCE(TRY_CAST(Insurances_1_SubscriberMiddle AS STRING),'') AS Insurances_1_SubscriberMiddle,
            COALESCE(TRY_CAST(Insurances_1_SubscriberState AS STRING),'') AS Insurances_1_SubscriberState,
            COALESCE(TRY_CAST(Insurances_1_SubscriberZip AS STRING),'') AS Insurances_1_SubscriberZip,
            COALESCE(TRY_CAST(LastUpdated AS STRING),'') AS LastUpdated,
            COALESCE(TRY_CAST(LastUpdatedUserId AS STRING),'') AS LastUpdatedUserId,
            COALESCE(TRY_CAST(LastUserUpdatedDate AS STRING),'') AS LastUserUpdatedDate,
            COALESCE(TRY_CAST(MediaCode AS STRING),'') AS MediaCode,
            COALESCE(TRY_CAST(NoteLastID AS BIGINT),0) AS NoteLastID,
            COALESCE(TRY_CAST(Notes AS STRING),'') AS Notes,
            COALESCE(TRY_CAST(ParentID AS STRING),'') AS ParentID,
            COALESCE(TRY_CAST(PatID AS STRING),'') AS PatID,
            COALESCE(TRY_CAST(PatientAddr1 AS STRING),'') AS PatientAddr1,
            COALESCE(TRY_CAST(PatientAddr2 AS STRING),'') AS PatientAddr2,
            COALESCE(TRY_CAST(PatientCity AS STRING),'') AS PatientCity,
            COALESCE(TRY_CAST(PatientCtlNo AS STRING),'') AS PatientCtlNo,
            COALESCE(TRY_CAST(PatientDOB AS STRING),'') AS PatientDOB,
            COALESCE(TRY_CAST(PatientFirst AS STRING),'') AS PatientFirst,
            COALESCE(TRY_CAST(PatientGender AS STRING),'') AS PatientGender,
            COALESCE(TRY_CAST(PatientLast AS STRING),'') AS PatientLast,
            COALESCE(TRY_CAST(PatientMiddle AS STRING),'') AS PatientMiddle,
            COALESCE(TRY_CAST(PatientState AS STRING),'') AS PatientState,
            COALESCE(TRY_CAST(PatientZip AS STRING),'') AS PatientZip,
            COALESCE(TRY_CAST(PayToAddr1 AS STRING),'') AS PayToAddr1,
            COALESCE(TRY_CAST(PayToCity AS STRING),'') AS PayToCity,
            COALESCE(TRY_CAST(PayToName AS STRING),'') AS PayToName,
            COALESCE(TRY_CAST(PayToProvID_NPI AS STRING),'') AS PayToProvID_NPI,
            COALESCE(TRY_CAST(PayToProvID_Taxonomy AS STRING),'') AS PayToProvID_Taxonomy,
            COALESCE(TRY_CAST(PayToState AS STRING),'') AS PayToState,
            COALESCE(TRY_CAST(PayToZip AS STRING),'') AS PayToZip,
            COALESCE(TRY_CAST(PayerMatchID AS STRING),'') AS PayerMatchID,
            COALESCE(TRY_CAST(PayerPartnerID AS STRING),'') AS PayerPartnerID,
            COALESCE(TRY_CAST(PaymentDate AS STRING),'') AS PaymentDate,
            COALESCE(TRY_CAST(PrintMail AS STRING),'') AS PrintMail,
            COALESCE(TRY_CAST(ProcedureVersion AS STRING),'') AS ProcedureVersion,
            COALESCE(TRY_CAST(ProvMatchID AS STRING),'') AS ProvMatchID,
            COALESCE(TRY_CAST(ProvPartnerID AS STRING),'') AS ProvPartnerID,
            COALESCE(TRY_CAST(ReferringFirst AS STRING),'') AS ReferringFirst,
            COALESCE(TRY_CAST(ReferringLast AS STRING),'') AS ReferringLast,
            COALESCE(TRY_CAST(ReferringMiddle AS STRING),'') AS ReferringMiddle,
            COALESCE(TRY_CAST(ReferringProvID_NPI AS STRING),'') AS ReferringProvID_NPI,
            COALESCE(TRY_CAST(ReimbursementAmount AS DECIMAL(10,2)),CAST(0 AS DECIMAL(10,2))) AS ReimbursementAmount,
            COALESCE(TRY_CAST(RelatedEmployment AS STRING),'') AS RelatedEmployment,
            COALESCE(TRY_CAST(ReleaseToDde AS BOOLEAN),false) AS ReleaseToDde,
            COALESCE(TRY_CAST(RemitClaimID AS STRING),'') AS RemitClaimID,
            COALESCE(TRY_CAST(RenderingEntType AS STRING),'') AS RenderingEntType,
            COALESCE(TRY_CAST(RenderingFirst AS STRING),'') AS RenderingFirst,
            COALESCE(TRY_CAST(RenderingLast AS STRING),'') AS RenderingLast,
            COALESCE(TRY_CAST(RenderingMiddle AS STRING),'') AS RenderingMiddle,
            COALESCE(TRY_CAST(RenderingProvID_NPI AS STRING),'') AS RenderingProvID_NPI,
            COALESCE(TRY_CAST(RenderingProvID_Taxonomy AS STRING),'') AS RenderingProvID_Taxonomy,
            COALESCE(TRY_CAST(RenderingSuffix AS STRING),'') AS RenderingSuffix,
            COALESCE(TRY_CAST(RuleOverrides AS STRING),'') AS RuleOverrides,
            COALESCE(TRY_CAST(ServiceAddr1 AS STRING),'') AS ServiceAddr1,
            COALESCE(TRY_CAST(ServiceAddr2 AS STRING),'') AS ServiceAddr2,
            COALESCE(TRY_CAST(ServiceCity AS STRING),'') AS ServiceCity,
            COALESCE(TRY_CAST(ServiceLastID AS BIGINT),0) AS ServiceLastID,
            COALESCE(TRY_CAST(ServiceName AS STRING),'') AS ServiceName,
            COALESCE(TRY_CAST(ServiceState AS STRING),'') AS ServiceState,
            COALESCE(TRY_CAST(ServiceZip AS STRING),'') AS ServiceZip,
            COALESCE(TRY_CAST(ServiceLineNo AS INT),0) AS ServiceLineNo,
            COALESCE(TRY_CAST(Services_ThroughDate AS STRING),'') AS Services_ThroughDate,
            COALESCE(TRY_CAST(Services_DiagnosisPointer AS STRING),'') AS Services_DiagnosisPointer,
            COALESCE(TRY_CAST(Services_OrderingMiddle AS STRING),'') AS Services_OrderingMiddle,
            COALESCE(TRY_CAST(Services_Charge AS DECIMAL(10,2)),CAST(0 AS DECIMAL(10,2))) AS Services_Charge,
            COALESCE(TRY_CAST(Services_OrderingProvID_NPI AS STRING),'') AS Services_OrderingProvID_NPI,
            COALESCE(TRY_CAST(Services_RenderingProvID_NPI AS STRING),'') AS Services_RenderingProvID_NPI,
            COALESCE(TRY_CAST(Services_Units AS INT),0) AS Services_Units,
            COALESCE(TRY_CAST(Services_HCPC AS STRING),'') AS Services_HCPC,
            COALESCE(TRY_CAST(Services_ServiceID AS INT),0) AS Services_ServiceID,
            COALESCE(TRY_CAST(Services_OrderingSuffix AS STRING),'') AS Services_OrderingSuffix,
            COALESCE(TRY_CAST(Services_PlaceService AS STRING),'') AS Services_PlaceService,
            COALESCE(TRY_CAST(Services_UnderpaymentAmount AS DECIMAL(10,2)),CAST(0 AS DECIMAL(10,2))) AS Services_UnderpaymentAmount,
            COALESCE(TRY_CAST(Services_OrderingFirst AS STRING),'') AS Services_OrderingFirst,
            COALESCE(TRY_CAST(Services_ReferringSuffix AS STRING),'') AS Services_ReferringSuffix,
            COALESCE(TRY_CAST(Services_OrderingLast AS STRING),'') AS Services_OrderingLast,
            COALESCE(TRY_CAST(Services_RenderingLast AS STRING),'') AS Services_RenderingLast,
            COALESCE(TRY_CAST(Services_FromDate AS STRING),'') AS Services_FromDate,
            COALESCE(TRY_CAST(Services_LineNo AS INT),0) AS Services_LineNo,
            COALESCE(TRY_CAST(SignatureOnFile AS STRING),'') AS SignatureOnFile,
            COALESCE(TRY_CAST(SourceFileID AS STRING),'') AS SourceFileID,
            COALESCE(TRY_CAST(StatementEnd AS STRING),'') AS StatementEnd,
            COALESCE(TRY_CAST(StatementStart AS STRING),'') AS StatementStart,
            COALESCE(TRY_CAST(TransID AS BIGINT),0) AS TransID,
            COALESCE(TRY_CAST(TransStatus AS STRING),'') AS TransStatus,
            COALESCE(TRY_CAST(TransType AS STRING),'') AS TransType,
            COALESCE(TRY_CAST(TransmitDate AS STRING),'') AS TransmitDate,
            COALESCE(TRY_CAST(UnderpaymentAmount AS BIGINT),0) AS UnderpaymentAmount,
            COALESCE(TRY_CAST(adj_icn AS STRING),'') AS adj_icn,
            COALESCE(TRY_CAST(_file_name AS STRING),'') AS _file_name,
            COALESCE(TRY_CAST(_load_timestamp AS TIMESTAMP),current_timestamp()) AS _load_timestamp
        FROM new_records_dedup
        )
        INSERT INTO {landing_flattened_table}
        SELECT * FROM new_records_final
    """)
except Exception as e:
    print(f"Error loading into {landing_flattened_table}: {e}")
    raise
