# %%
source_catalog = dbutils.widgets.get("source_catalog")
source_schema = dbutils.widgets.get("source_schema")

target_catalog = dbutils.widgets.get("target_catalog")
target_schema = dbutils.widgets.get("target_schema")

# %%
source_target_pairs = [
    (f"/Volumes/{source_catalog}/{source_schema}/ability/claims/", f"/Volumes/{target_catalog}/{target_schema}/ability/claims/"),
    (f"/Volumes/{source_catalog}/{source_schema}/ability/remits/", f"/Volumes/{target_catalog}/{target_schema}/ability/remits/"),
    (f"/Volumes/{source_catalog}/{source_schema}/ability/remits_payments/", f"/Volumes/{target_catalog}/{target_schema}/ability/remits_payments/"),
    (f"/Volumes/{source_catalog}/{source_schema}/ability/val_claims_details/", f"/Volumes/{target_catalog}/{target_schema}/ability/val_claims_details/"),
    (f"/Volumes/{source_catalog}/{source_schema}/ability/val_remits_details/", f"/Volumes/{target_catalog}/{target_schema}/ability/val_remits_details/"),
    (f"/Volumes/{source_catalog}/{source_schema}/ability/val_remits_payments_details/", f"/Volumes/{target_catalog}/{target_schema}/ability/val_remits_payments_details/"),
    (f"/Volumes/{source_catalog}/{source_schema}/ability/err_claims_details/", f"/Volumes/{target_catalog}/{target_schema}/ability/err_claims_details/"),
    (f"/Volumes/{source_catalog}/{source_schema}/ability/err_remits_details/", f"/Volumes/{target_catalog}/{target_schema}/ability/err_remits_details/"),
    (f"/Volumes/{source_catalog}/{source_schema}/ability/err_remits_payments_details/", f"/Volumes/{target_catalog}/{target_schema}/ability/err_remits_payments_details/")
]

for source_path, target_path in source_target_pairs:
    dbutils.fs.cp(source_path, target_path, recurse=True)
