# %%
cubhub_claims = dbutils.widgets.get("cubhub_claims")
cubhub_charges = dbutils.widgets.get("cubhub_charges")
cubhub_transactions = dbutils.widgets.get("cubhub_transactions")

cubhub_claims_history = dbutils.widgets.get("cubhub_claims_history")
cubhub_charges_history = dbutils.widgets.get("cubhub_charges_history")
cubhub_transactions_history = dbutils.widgets.get("cubhub_transactions_history")

# %%
# %skip
cubhub_claims = "dev_gold_lakehouse.metric_layer.cubhub_ac_claims"
cubhub_charges = "dev_gold_lakehouse.metric_layer.cubhub_ac_charges"
cubhub_transactions = "dev_gold_lakehouse.metric_layer.cubhub_ac_transactions"

cubhub_claims_history = "dev_gold_lakehouse.metric_layer.cubhub_ac_claims_history"
cubhub_charges_history = "dev_gold_lakehouse.metric_layer.cubhub_ac_charges_history"
cubhub_transactions_history = "dev_gold_lakehouse.metric_layer.cubhub_ac_transactions_history"

# %%
count = spark.sql(f"SELECT COUNT(*) as cnt FROM {cubhub_claims_history}").collect()[0]['cnt']
if count == 0 :
    print(f"Full load for {cubhub_claims_history} executed")
    spark.sql(f"""
    INSERT INTO {cubhub_claims_history} (
    OfficeId,
    ClaimId,
    ServiceStart,
    ServiceEnd,
    AdmitDate,
    DischargeDate,
    MedicalRecordNumber,
    Street1,
    Street2,
    City,
    State,
    ZipCode,
    DateOfBirth,
    FirstName,
    LastName,
    MiddleName,
    Gender,
    PhoneNumber,
    SocialSecurityNumber,
    OrderingPhysicianNpi,
    OrderingPhysicianFirstName,
    OrderingPhysicianLastName,
    OrderingPhysicianId,
    PrimaryPayerSubscriberId,
    ClaimSubscriberId,
    Balance,
    ClaimNumber,
    EvvAggregator,
    ExpectedTotal,
    DateBilled,
    Adjustments,
    Payments,
    TotalBilled,
    Npi,
    BillingPeriod,
    PayerStreet1,
    PayerStreet2,
    PayerCity,
    PayerState,
    PayerZipCode,
    PayerName,
    PayerId,
    MedicaidProgram,
    CobBenefitDate,
    CobDenialReason,
    CobEffectiveDate,
    CobLevel,
    CobPrimaryInsurance,
    CobSplitDecision,
    CobStatus,
    CobType,
    FinancialClassAbbreviation,
    FinancialClass,
    OfficeExternalId,
    PrimaryDiagnosis,
    LoadDate,
    FileName
    )
    SELECT
    TRY_CAST(OfficeId AS INT),
    TRY_CAST(ClaimId AS INT),
    TRY_CAST(ServiceStart AS STRING),
    TRY_CAST(ServiceEnd AS STRING),
    TRY_CAST(AdmitDate AS STRING),
    TRY_CAST(DischargeDate AS STRING),
    TRY_CAST(MedicalRecordNumber AS STRING),
    TRY_CAST(Street1 AS STRING),
    TRY_CAST(Street2 AS STRING),
    TRY_CAST(City AS STRING),
    TRY_CAST(State AS STRING),
    TRY_CAST(ZipCode AS STRING),
    TRY_CAST(DateOfBirth AS STRING),
    TRY_CAST(FirstName AS STRING),
    TRY_CAST(LastName AS STRING),
    TRY_CAST(MiddleName AS STRING),
    TRY_CAST(Gender AS STRING),
    TRY_CAST(PhoneNumber AS STRING),
    TRY_CAST(SocialSecurityNumber AS STRING),
    TRY_CAST(OrderingPhysicianNpi AS STRING),
    TRY_CAST(OrderingPhysicianFirstName AS STRING),
    TRY_CAST(OrderingPhysicianLastName AS STRING),
    TRY_CAST(OrderingPhysicianId AS INT),
    TRY_CAST(PrimaryPayerSubscriberId AS STRING),
    TRY_CAST(ClaimSubscriberId AS STRING),
    TRY_CAST(Balance AS DOUBLE),
    TRY_CAST(ClaimNumber AS STRING),
    TRY_CAST(EvvAggregator AS STRING),
    TRY_CAST(ExpectedTotal AS DOUBLE),
    TRY_CAST(DateBilled AS STRING),
    TRY_CAST(Adjustments AS INT),
    TRY_CAST(Payments AS DOUBLE),
    TRY_CAST(TotalBilled AS DOUBLE),
    TRY_CAST(Npi AS STRING),
    TRY_CAST(BillingPeriod AS STRING),
    TRY_CAST(PayerStreet1 AS STRING),
    TRY_CAST(PayerStreet2 AS STRING),
    TRY_CAST(PayerCity AS STRING),
    TRY_CAST(PayerState AS STRING),
    TRY_CAST(PayerZipCode AS STRING),
    TRY_CAST(PayerName AS STRING),
    TRY_CAST(PayerId AS INT),
    TRY_CAST(MedicaidProgram AS STRING),
    TRY_CAST(CobBenefitDate AS STRING),
    TRY_CAST(CobDenialReason AS STRING),
    TRY_CAST(CobEffectiveDate AS STRING),
    TRY_CAST(CobLevel AS STRING),
    TRY_CAST(CobPrimaryInsurance AS STRING),
    TRY_CAST(CobSplitDecision AS STRING),
    TRY_CAST(CobStatus AS STRING),
    TRY_CAST(CobType AS STRING),
    TRY_CAST(FinancialClassAbbreviation AS STRING),
    TRY_CAST(FinancialClass AS VARCHAR(100)),
    TRY_CAST(OfficeExternalId AS STRING),
    TRY_CAST(PrimaryDiagnosis AS STRING),
    TRY_CAST(Loaddate AS DATE),
    TRY_CAST(FileName AS STRING)
    FROM prd_bronze_raw.mart_bkp.alphacollector_claims_history;
    """)
count = spark.sql(f"SELECT COUNT(*) as cnt FROM {cubhub_charges_history}").collect()[0]['cnt']
if count == 0 :
    print(f"Full load for {cubhub_charges_history} executed")
    spark.sql(f"""
    INSERT INTO {cubhub_charges_history} (
    OfficeId,
    ChargeId,
    ClaimId,
    AssignmentId,
    AuthorizationNumber,
    HcsPcsCode,
    RevenueCode,
    BilledHours,
    BilledUnits,
    BilledVisits,
    Rate,
    RateType,
    DiscountAmount,
    DiscountType,
    CalculatedAmount,
    DiagnosisCode,
    TotalBilled,
    ClaimNumber,
    OfficeExternalId,
    DateOfService,
    DateBilled,
    Skill,
    FinancialClass,
    FinancialClassAbbreviation,
    Modifier1,
    Modifier2,
    Modifier3,
    Modifier4,
    Discipline,
    ServiceCodeDescription,
    LoadDate,
    FileName
    )
    SELECT
    TRY_CAST(OfficeId AS INT),
    TRY_CAST(ChargeId AS INT),
    TRY_CAST(ClaimId AS INT),
    TRY_CAST(AssignmentId AS INT),
    TRY_CAST(AuthorizationNumber AS STRING),
    TRY_CAST(HcsPcsCode AS STRING),
    TRY_CAST(RevenueCode AS STRING),
    TRY_CAST(BilledHours AS DOUBLE),
    TRY_CAST(BilledUnits AS DOUBLE),
    TRY_CAST(BilledVisits AS INT),
    TRY_CAST(Rate AS DOUBLE),
    TRY_CAST(RateType AS STRING),
    TRY_CAST(DiscountAmount AS DOUBLE),
    TRY_CAST(DiscountType AS STRING),
    TRY_CAST(CalculatedAmount AS DOUBLE),
    TRY_CAST(DiagnosisCode AS STRING),
    TRY_CAST(TotalBilled AS DOUBLE),
    TRY_CAST(ClaimNumber AS STRING),
    TRY_CAST(OfficeExternalId AS VARCHAR(100)),
    TRY_CAST(DateOfService AS STRING),
    TRY_CAST(DateBilled AS STRING),
    TRY_CAST(Skill AS STRING),
    TRY_CAST(FinancialClass AS STRING),
    TRY_CAST(FinancialClassAbbreviation AS STRING),
    TRY_CAST(Modifier1 AS STRING),
    TRY_CAST(Modifier2 AS STRING),
    TRY_CAST(Modifier3 AS STRING),
    TRY_CAST(Modifier4 AS STRING),
    TRY_CAST(Discipline AS STRING),
    TRY_CAST(ServiceCodeDescription AS STRING),
    TRY_CAST(LoadDate AS DATE),
    TRY_CAST(FileName AS STRING)
    FROM prd_bronze_raw.mart_bkp.alphacollector_charges_history;
    """)
count = spark.sql(f"SELECT COUNT(*) as cnt FROM {cubhub_transactions_history}").collect()[0]['cnt']
if count == 0 :
    print(f"Full load for {cubhub_transactions_history} executed")
    spark.sql(f"""
    INSERT INTO {cubhub_transactions_history} (
    OfficeId,
    ClaimId,
    TransCode,
    TransDesc,
    TransType,
    EntryDate,
    PaymentId,
    TransAmt,
    BatchId,
    TransDate,
    BillingLedgerDetailId,
    OfficeExternalId,
    ClaimNumber,
    Loaddate,
    FileName,
    ReportingWeekEndingDate
    )
    SELECT
    TRY_CAST(OfficeId AS INT),
    TRY_CAST(ClaimId AS INT),
    TRY_CAST(TransCode AS STRING),
    TRY_CAST(TransDesc AS STRING),
    TRY_CAST(TransType AS STRING),
    TRY_CAST(EntryDate AS STRING),
    TRY_CAST(PaymentId AS STRING),
    TRY_CAST(TransAmt AS DOUBLE),
    TRY_CAST(BatchId AS STRING),
    TRY_CAST(TransDate AS STRING),
    TRY_CAST(BillingLedgerDetailId AS INT),
    TRY_CAST(OfficeExternalId AS VARCHAR(100)),
    TRY_CAST(ClaimNumber AS STRING),
    TRY_CAST(Loaddate AS DATE),
    TRY_CAST(FileName AS STRING),
    TRY_CAST(ReportingWeekEndingDate AS STRING)
    FROM prd_bronze_raw.mart_bkp.alphacollector_transactions_history;
    """)

# %%
spark.sql(f"""
INSERT INTO {cubhub_claims_history} (
  OfficeId,
  ClaimId,
  ServiceStart,
  ServiceEnd,
  AdmitDate,
  DischargeDate,
  MedicalRecordNumber,
  Street1,
  Street2,
  City,
  State,
  ZipCode,
  DateOfBirth,
  FirstName,
  LastName,
  MiddleName,
  Gender,
  PhoneNumber,
  SocialSecurityNumber,
  OrderingPhysicianNpi,
  OrderingPhysicianFirstName,
  OrderingPhysicianLastName,
  OrderingPhysicianId,
  PrimaryPayerSubscriberId,
  ClaimSubscriberId,
  Balance,
  ClaimNumber,
  EvvAggregator,
  ExpectedTotal,
  DateBilled,
  Adjustments,
  Payments,
  TotalBilled,
  Npi,
  BillingPeriod,
  PayerStreet1,
  PayerStreet2,
  PayerCity,
  PayerState,
  PayerZipCode,
  PayerName,
  PayerId,
  MedicaidProgram,
  CobBenefitDate,
  CobDenialReason,
  CobEffectiveDate,
  CobLevel,
  CobPrimaryInsurance,
  CobSplitDecision,
  CobStatus,
  CobType,
  FinancialClassAbbreviation,
  FinancialClass,
  OfficeExternalId,
  PrimaryDiagnosis,
  LoadDate,
  FileName
)
SELECT
  OfficeId,
  ClaimId,
  ServiceStart,
  ServiceEnd,
  AdmitDate,
  DischargeDate,
  MedicalRecordNumber,
  Street1,
  Street2,
  City,
  State,
  ZipCode,
  DateOfBirth,
  FirstName,
  LastName,
  MiddleName,
  Gender,
  PhoneNumber,
  SocialSecurityNumber,
  OrderingPhysicianNpi,
  OrderingPhysicianFirstName,
  OrderingPhysicianLastName,
  OrderingPhysicianId,
  PrimaryPayerSubscriberId,
  ClaimSubscriberId,
  Balance,
  ClaimNumber,
  EvvAggregator,
  ExpectedTotal,
  DateBilled,
  Adjustments,
  Payments,
  TotalBilled,
  Npi,
  BillingPeriod,
  PayerStreet1,
  PayerStreet2,
  PayerCity,
  PayerState,
  PayerZipCode,
  PayerName,
  PayerId,
  MedicaidProgram,
  CobBenefitDate,
  CobDenialReason,
  CobEffectiveDate,
  CobLevel,
  CobPrimaryInsurance,
  CobSplitDecision,
  CobStatus,
  CobType,
  FinancialClassAbbreviation,
  FinancialClass,
  OfficeExternalId,
  PrimaryDiagnosis,
  LoadDate,
  FileName
FROM {cubhub_claims}
""")

# %%
spark.sql(f"""
INSERT INTO {cubhub_charges_history} (
  OfficeId,
  ChargeId,
  ClaimId,
  AssignmentId,
  AuthorizationNumber,
  HcsPcsCode,
  RevenueCode,
  BilledHours,
  BilledUnits,
  BilledVisits,
  Rate,
  RateType,
  DiscountAmount,
  DiscountType,
  CalculatedAmount,
  DiagnosisCode,
  TotalBilled,
  ClaimNumber,
  OfficeExternalId,
  DateOfService,
  DateBilled,
  Skill,
  FinancialClass,
  FinancialClassAbbreviation,
  Modifier1,
  Modifier2,
  Modifier3,
  Modifier4,
  Discipline,
  ServiceCodeDescription,
  LoadDate,
  FileName
)
SELECT
  OfficeId,
  ChargeId,
  ClaimId,
  AssignmentId,
  AuthorizationNumber,
  HcsPcsCode,
  RevenueCode,
  BilledHours,
  BilledUnits,
  BilledVisits,
  Rate,
  RateType,
  DiscountAmount,
  DiscountType,
  CalculatedAmount,
  DiagnosisCode,
  TotalBilled,
  ClaimNumber,
  OfficeExternalId,
  DateOfService,
  DateBilled,
  Skill,
  FinancialClass,
  FinancialClassAbbreviation,
  Modifier1,
  Modifier2,
  Modifier3,
  Modifier4,
  Discipline,
  ServiceCodeDescription,
  LoadDate,
  FileName
FROM {cubhub_charges}
""")

# %%
spark.sql(f"""
INSERT INTO {cubhub_transactions_history} (
  OfficeId,
  ClaimId,
  TransCode,
  TransDesc,
  TransType,
  EntryDate,
  PaymentId,
  TransAmt,
  BatchId,
  TransDate,
  BillingLedgerDetailId,
  OfficeExternalId,
  ClaimNumber,
  Loaddate,
  FileName,
  ReportingWeekEndingDate
)
SELECT
  OfficeId,
  ClaimId,
  TransCode,
  TransDesc,
  TransType,
  EntryDate,
  PaymentId,
  TransAmt,
  BatchId,
  TransDate,
  BillingLedgerDetailId,
  OfficeExternalId,
  ClaimNumber,
  Loaddate,
  FileName,
  ReportingWeekEndingDate
FROM {cubhub_transactions}
""")
